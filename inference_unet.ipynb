# %%
import os, sys
PROJECT_ROOT = os.path.abspath(".")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.inference.enhanced_unet_infer import run_inference

img_path = "./LiTS17/volume-XX.nii"          # change
mask_path = "./LiTS17/segmentation-XX.nii"   # change (or None)
slice_idx = 150
model_path = "./models/best_model.pth"

run_inference(
    img_path=img_path,
    mask_path=mask_path,
    slice_idx=slice_idx,
    model_path=model_path,
)
